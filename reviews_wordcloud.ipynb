# %%
# Import our dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import warnings
% matplotlib inline
warnings.filterwarnings('ignore')
# Out:
# UsageError: Line magic function `%` not found.

# %%
# import Reviews csv for python word cloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
review_df = pd.read_csv('./Resources/reviews.csv' )
review_df.head(10)
# Out:
#    listing_id      id        date  reviewer_id   reviewer_name  \
# 0        5269  289800  2011-05-31       452192            Gert
# 1      157141  398785  2011-07-26       561617       Kimberlee
# 2      157141  440285  2011-08-12       126312  Scott And Liya
# 3      157141  490965  2011-08-31       862407            Paul
# 4      157141  506168  2011-09-06       568883           Tanya
# 5      157141  551635  2011-09-20      1114068            Neil
# 6      157141  611487  2011-10-09      1031311          Katrin
# 7      157141  663998  2011-10-25      1265687            Tomi
# 8      157141  702571  2011-11-08      1225140          Steven
# 9      157141  727484  2011-11-18      1003664        Marianne
#
#                                             comments
# 0  Very warm welcome. Great place to stay.  Highl...
# 1  My sister stayed at this wounderful place righ...
# 2  My husband and I were camping in the North Sho...
# 3      Comfortable apartment, beautiful quiet beach.
# ...

# %%
# Dropping columns
review_df.drop(columns=['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name'], inplace=True)
review_df.head()
# Out:
#                                             comments
# 0  Very warm welcome. Great place to stay.  Highl...
# 1  My sister stayed at this wounderful place righ...
# 2  My husband and I were camping in the North Sho...
# 3      Comfortable apartment, beautiful quiet beach.
# 4  Roland was a great host with an awesome space!...

# %%
# Show obersavations and features
print("There are {} observations and {} features in this dataset. \n".format(review_df.shape[0],review_df.shape[1]))
# Out:
# There are 847888 observations and 1 features in this dataset.

# %%
# Start with one review:
text = review_df.comments[1]

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Display columns of the review DataFrame
review_df.columns
# Out:
# Index(['comments'], dtype='object')

# %%
# Comments column 
review_df['comments']
# Out:
# 0         Very warm welcome. Great place to stay.  Highl...
# 1         My sister stayed at this wounderful place righ...
# 2         My husband and I were camping in the North Sho...
# 3             Comfortable apartment, beautiful quiet beach.
# 4         Roland was a great host with an awesome space!...
#                                 ...
# 847883    The house was right at the beach and we would ...
# 847884    One of the best stays I’ve had. Super easy to ...
# 847885    As a family of nine getting together from all ...
# 847886    Great host. Amazing place to stay off the busy...
# 847887    Such a lovely place and the North Shore was ju...
# Name: comments, Length: 847888, dtype: object

# %%
# lower max_font_size, change the maximum number of word and lighten the background:
wordcloud = WordCloud(max_font_size=50, max_words=113, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#review_df = ''.join(map(str, review_df))
review_df['comments'] = review_df['comments'].fillna(value='')

# %%
# Bringing all text from the comments column
all_text = " ".join(comment for comment in review_df.comments)
print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 113 words in the combination of all review.

# %%
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["place", "Great", "recommended", "Thank", "stay", 'welcome', 'Highly', 'warm','wounderful', 'enjoyed', 'sister',
                 'every','min','able', 'want', 'made', 'lot', 'time', 'thing', 'br', 'much', 'need', 'needed', 'stayed', 'loved',
                 'day', 'plenty', 'everything', 'check', 'really', 'love', 'host', 'use', 'amenitie', 'recommend', 'will', 'unit',
                 'perfect', 'hosts', 'Airbnb', 'fantastic', 'enjoy', 'one', 'feel', 'trip', 'find', 'u', 'definitely', 'us', 'night',
                 's', 'make', 'come back', 'chair', 'staying'])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="black", max_words=35, max_font_size=60).generate(all_text)

# Display the generated image:
# the matplotlib way:
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from os import path
from PIL import Image

# %%
# Creating a Mask for our WordCloud
mask =  np.array(Image.open('img/hawaii_islands.jpg'))
mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
# Generating a WordCloud
wc = WordCloud(background_color="white", max_words=200, mask=mask,
    stopwords=stopwords, colormap='tab10')

# generate wordcloud
wc.generate(all_text)

plt.figure(figsize=[50,25])
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# Generating a WordCloud
wc_dark = WordCloud(background_color="black", max_words=500, mask=mask,
    stopwords=stopwords, colormap='tab10')

# generate wordcloud
wc_dark.generate(all_text)

plt.figure(figsize=[50,25])
plt.imshow(wc_dark, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# Generating a WordCloud
wc_new = WordCloud(background_color="white", max_words=200, mask=mask,
    stopwords=stopwords, colormap='magma')

# generate wordcloud
wc_new.generate(all_text)

plt.figure(figsize=[50,25])
plt.imshow(wc_new, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# Generating a WordCloud
wc_color = WordCloud(mode = 'RGB', background_color='rgb(12, 186, 166)', max_words=1000, mask=mask,
    stopwords=stopwords, colormap='tab10')

# generate wordcloud
wc_color.generate(all_text)

plt.figure(figsize=[50,25])
plt.imshow(wc_color, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# Generating a WordCloud
wc_color_new = WordCloud(mode = 'RGB', background_color='rgb(0, 84, 119)', max_words=500, mask=mask,
    stopwords=stopwords, colormap='tab10', contour_width=0.5, contour_color='whitesmoke')

# generate wordcloud
wc_color_new.generate(all_text)

plt.figure(figsize=[50,25])
plt.imshow(wc_color_new, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# new wc image with background
image_colors = ImageColorGenerator(mask)

wc_background = WordCloud(stopwords=stopwords, 
                        background_color="white", 
                        mode="RGBA", 
                        max_words=1000, 
                        #contour_width=3, 
                        repeat=True,
                        mask=mask,
                        colormap='summer')

wc_background.generate(all_text)
wc_background.recolor(color_func = image_colors)

plt.figure(figsize=[50,25])
plt.imshow(wc_background)
plt.axis("off")
plt.show()

# %%
# WordCloud image with mask showing
island_img = Image.fromarray(wc.to_array())
island_mask_img = Image.fromarray(mask)

new_img = Image.blend(island_img, 
                     island_mask_img, 
                      0.5)

plt.figure(figsize=[100,50])
plt.imshow(new_img)
plt.axis("off")
plt.show()
